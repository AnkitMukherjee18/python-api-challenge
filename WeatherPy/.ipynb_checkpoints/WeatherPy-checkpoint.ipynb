# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 604

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?q=London,uk&APPID=41e70f5c693d3d10917e45395afb7610"
    
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-"*30)

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url.format(city)
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-"*30)
print("Data Retrieval Complete      ")
print("-"*30)
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | olonkinbyen
# Processing Record 2 of Set 1 | bethel
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | grytviken
# Processing Record 5 of Set 1 | minas de marcona
# Processing Record 6 of Set 1 | georgetown
# Processing Record 7 of Set 1 | gangneung
# Processing Record 8 of Set 1 | sao jose da coroa grande
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | hasaki
# Processing Record 12 of Set 1 | ancud
# Processing Record 13 of Set 1 | saint-joseph
# Processing Record 14 of Set 1 | uyuni
# Processing Record 15 of Set 1 | san sebastian de la gomera
# Processing Record 16 of Set 1 | tahoua
# Processing Record 17 of Set 1 | le morne-rouge
# Processing Record 18 of Set 1 | talnakh
# Processing Record 19 of Set 1 | edinburgh of the seven seas
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | al bardiyah
# Processing Record 22 of Set 1 | anabar
# Processing Record 23 of Set 1 | opuwo
# Processing Record 24 of Set 1 | naze
# Processing Record 25 of Set 1 | stanley
# Processing Record 26 of Set 1 | puerto natales
# Processing Record 27 of Set 1 | papatowai
# Processing Record 28 of Set 1 | morehead city
# Processing Record 29 of Set 1 | wailua homesteads
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | asau village
# Processing Record 32 of Set 1 | ruteng
# Processing Record 33 of Set 1 | kpandae
# Processing Record 34 of Set 1 | blackmans bay
# Processing Record 35 of Set 1 | mopti
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | adamstown
# Processing Record 38 of Set 1 | yuzhno-kurilsk
# Processing Record 39 of Set 1 | newman
# Processing Record 40 of Set 1 | waitangi
# Processing Record 41 of Set 1 | hawaiian paradise park
# Processing Record 42 of Set 1 | lerwick
# Processing Record 43 of Set 1 | invercargill
# Processing Record 44 of Set 1 | itarare
# Processing Record 45 of Set 1 | taiohae
# Processing Record 46 of Set 1 | badger
# Processing Record 47 of Set 1 | udachny
# Processing Record 48 of Set 1 | moree
# Processing Record 49 of Set 1 | devinuwara
# Processing Record 50 of Set 1 | salalah
# Processing Record 0 of Set 2 | margaret river
# Processing Record 1 of Set 2 | saldanha
# Processing Record 2 of Set 2 | dauphin
# Processing Record 3 of Set 2 | port lincoln
# Processing Record 4 of Set 2 | bilibino
# Processing Record 5 of Set 2 | broken hill
# Processing Record 6 of Set 2 | tazovsky
# Processing Record 7 of Set 2 | meizhou
# Processing Record 8 of Set 2 | kodiak
# Processing Record 9 of Set 2 | ilulissat
# Processing Record 10 of Set 2 | kidal
# Processing Record 11 of Set 2 | port elizabeth
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | vorgashor
# Processing Record 14 of Set 2 | lihue
# Processing Record 15 of Set 2 | tiznit
# Processing Record 16 of Set 2 | port mathurin
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | ivdel'
# Processing Record 19 of Set 2 | ust-nera
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | tukrah
# Processing Record 22 of Set 2 | mount gambier
# Processing Record 23 of Set 2 | chulym
# Processing Record 24 of Set 2 | lata
# Processing Record 25 of Set 2 | kabalo
# Processing Record 26 of Set 2 | chandbali
# Processing Record 27 of Set 2 | ulladulla
# Processing Record 28 of Set 2 | taksimo
# Processing Record 29 of Set 2 | tromso
# Processing Record 30 of Set 2 | happy valley-goose bay
# Processing Record 31 of Set 2 | kariba
# Processing Record 32 of Set 2 | west island
# Processing Record 33 of Set 2 | bocaiuva
# Processing Record 34 of Set 2 | edd
# Processing Record 35 of Set 2 | muli
# Processing Record 36 of Set 2 | ushuaia
# Processing Record 37 of Set 2 | porbandar
# Processing Record 38 of Set 2 | inirida
# Processing Record 39 of Set 2 | nanao
# Processing Record 40 of Set 2 | port-vila
# Processing Record 41 of Set 2 | tolanaro
# Processing Record 42 of Set 2 | winter garden
# Processing Record 43 of Set 2 | al kharijah
# Processing Record 44 of Set 2 | sinabang
# Processing Record 45 of Set 2 | east london
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | darwin
# Processing Record 48 of Set 2 | jaen
# Processing Record 49 of Set 2 | hamilton
# Processing Record 0 of Set 3 | weno
# Processing Record 1 of Set 3 | queenstown
# Processing Record 2 of Set 3 | pacific grove
# Processing Record 3 of Set 3 | hermanus
# Processing Record 4 of Set 3 | codrington
# Processing Record 5 of Set 3 | uturoa
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | iskateley
# Processing Record 8 of Set 3 | kunming
# Processing Record 9 of Set 3 | tiksi
# Processing Record 10 of Set 3 | cockburn town
# Processing Record 11 of Set 3 | dunedin
# Processing Record 12 of Set 3 | orneta
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | st. john's
# Processing Record 15 of Set 3 | shenkursk
# Processing Record 16 of Set 3 | khandyga
# Processing Record 17 of Set 3 | gueltat zemmour
# Processing Record 18 of Set 3 | cabo san lucas
# Processing Record 19 of Set 3 | malpe
# Processing Record 20 of Set 3 | zaysan
# Processing Record 21 of Set 3 | merizo village
# Processing Record 22 of Set 3 | sitka
# Processing Record 23 of Set 3 | malvan
# Processing Record 24 of Set 3 | rumoi
# Processing Record 25 of Set 3 | libreville
# Processing Record 26 of Set 3 | nova olinda do norte
# Processing Record 27 of Set 3 | kavieng
# Processing Record 28 of Set 3 | magistral'nyy
# Processing Record 29 of Set 3 | lospalos
# Processing Record 30 of Set 3 | isafjordur
# Processing Record 31 of Set 3 | villa madero
# Processing Record 32 of Set 3 | puerto baquerizo moreno
# Processing Record 33 of Set 3 | afaahiti
# Processing Record 34 of Set 3 | el haouaria
# Processing Record 35 of Set 3 | tralee
# Processing Record 36 of Set 3 | mersa matruh
# Processing Record 37 of Set 3 | tura
# Processing Record 38 of Set 3 | susuman
# Processing Record 39 of Set 3 | cortez
# Processing Record 40 of Set 3 | anadyr
# Processing Record 41 of Set 3 | xianning
# Processing Record 42 of Set 3 | fuglafjordur
# Processing Record 43 of Set 3 | atafu village
# Processing Record 44 of Set 3 | tomatlan
# Processing Record 45 of Set 3 | tanumah
# Processing Record 46 of Set 3 | mata-utu
# Processing Record 47 of Set 3 | iqaluit
# Processing Record 48 of Set 3 | macapa
# Processing Record 49 of Set 3 | qaqortoq
# Processing Record 0 of Set 4 | broome
# Processing Record 1 of Set 4 | turlock
# Processing Record 2 of Set 4 | nguigmi
# Processing Record 3 of Set 4 | yanchep
# Processing Record 4 of Set 4 | blenheim
# Processing Record 5 of Set 4 | flying fish cove
# Processing Record 6 of Set 4 | whitehorse
# Processing Record 7 of Set 4 | faya-largeau
# Processing Record 8 of Set 4 | kingston
# Processing Record 9 of Set 4 | kailua-kona
# Processing Record 10 of Set 4 | polyarnyy
# Processing Record 11 of Set 4 | onchan
# Processing Record 12 of Set 4 | azna
# Processing Record 13 of Set 4 | qamdo
# Processing Record 14 of Set 4 | eraan
# Processing Record 15 of Set 4 | nishinoomote
# Processing Record 16 of Set 4 | port alfred
# Processing Record 17 of Set 4 | golfito
# Processing Record 18 of Set 4 | grevena
# Processing Record 19 of Set 4 | san jose de jachal
# Processing Record 20 of Set 4 | shima
# Processing Record 21 of Set 4 | enewetak
# Processing Record 22 of Set 4 | scottburgh
# Processing Record 23 of Set 4 | hami
# Processing Record 24 of Set 4 | bubaque
# Processing Record 25 of Set 4 | princeton
# Processing Record 26 of Set 4 | gros morne
# Processing Record 27 of Set 4 | rosa zarate
# Processing Record 28 of Set 4 | okakarara
# Processing Record 29 of Set 4 | daugavpils
# Processing Record 30 of Set 4 | ulsteinvik
# Processing Record 31 of Set 4 | kerikeri
# Processing Record 32 of Set 4 | karwar
# Processing Record 33 of Set 4 | yangor
# Processing Record 34 of Set 4 | regente feijo
# Processing Record 35 of Set 4 | beberibe
# Processing Record 36 of Set 4 | meiganga
# Processing Record 37 of Set 4 | floro
# Processing Record 38 of Set 4 | maceio
# Processing Record 39 of Set 4 | karukh
# Processing Record 40 of Set 4 | selfoss
# Processing Record 41 of Set 4 | lemvig
# Processing Record 42 of Set 4 | college
# Processing Record 43 of Set 4 | las lomitas
# Processing Record 44 of Set 4 | walvis bay
# Processing Record 45 of Set 4 | chapaev
# Processing Record 46 of Set 4 | akjoujt
# Processing Record 47 of Set 4 | olinda
# Processing Record 48 of Set 4 | labytnangi
# Processing Record 49 of Set 4 | lubuklinggau
# Processing Record 0 of Set 5 | emerald
# Processing Record 1 of Set 5 | souillac
# Processing Record 2 of Set 5 | mabaruma
# Processing Record 3 of Set 5 | gobabis
# Processing Record 4 of Set 5 | narvik
# Processing Record 5 of Set 5 | egilsstadir
# Processing Record 6 of Set 5 | lebu
# Processing Record 7 of Set 5 | toga village
# Processing Record 8 of Set 5 | baykal'sk
# Processing Record 9 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 10 of Set 5 | middelburg
# Processing Record 11 of Set 5 | viedma
# Processing Record 12 of Set 5 | keflavik
# Processing Record 13 of Set 5 | salinopolis
# Processing Record 14 of Set 5 | kristiansund
# Processing Record 15 of Set 5 | daru
# Processing Record 16 of Set 5 | palikir - national government center
# Processing Record 17 of Set 5 | arraial do cabo
# Processing Record 18 of Set 5 | anar darah
# Processing Record 19 of Set 5 | jamestown
# Processing Record 20 of Set 5 | luderitz
# Processing Record 21 of Set 5 | crockett
# Processing Record 22 of Set 5 | umba
# Processing Record 23 of Set 5 | ts'alenjikha
# Processing Record 24 of Set 5 | luwuk
# Processing Record 25 of Set 5 | hayma'
# Processing Record 26 of Set 5 | haiku-pauwela
# Processing Record 27 of Set 5 | nolinsk
# Processing Record 28 of Set 5 | anse royale
# Processing Record 29 of Set 5 | bratca
# Processing Record 30 of Set 5 | dampit
# Processing Record 31 of Set 5 | kralendijk
# Processing Record 32 of Set 5 | kisanga
# Processing Record 33 of Set 5 | sterling
# Processing Record 34 of Set 5 | klyuchi
# Processing Record 35 of Set 5 | safford
# Processing Record 36 of Set 5 | mount pleasant
# Processing Record 37 of Set 5 | bereznik
# Processing Record 38 of Set 5 | ladario
# Processing Record 39 of Set 5 | kupang
# Processing Record 40 of Set 5 | kill devil hills
# Processing Record 41 of Set 5 | fillmore
# Processing Record 42 of Set 5 | glogowek
# Processing Record 43 of Set 5 | kavaratti
# Processing Record 44 of Set 5 | yuxi
# Processing Record 45 of Set 5 | altamira
# Processing Record 46 of Set 5 | montepuez
# Processing Record 47 of Set 5 | kapuskasing
# Processing Record 48 of Set 5 | tazacorte
# Processing Record 49 of Set 5 | usogorsk
# Processing Record 0 of Set 6 | lagunas
# Processing Record 1 of Set 6 | lodja
# Processing Record 2 of Set 6 | thompson
# Processing Record 3 of Set 6 | alotau
# Processing Record 4 of Set 6 | payakumbuh
# Processing Record 5 of Set 6 | nelson bay
# Processing Record 6 of Set 6 | cova figueira
# Processing Record 7 of Set 6 | nouadhibou
# Processing Record 8 of Set 6 | vilyuysk
# Processing Record 9 of Set 6 | antsiranana
# Processing Record 10 of Set 6 | san patricio
# Processing Record 11 of Set 6 | saint croix
# Processing Record 12 of Set 6 | ilha de mocambique
# Processing Record 13 of Set 6 | fort bragg
# Processing Record 14 of Set 6 | aasiaat
# Processing Record 15 of Set 6 | bangassou
# Processing Record 16 of Set 6 | belmonte
# Processing Record 17 of Set 6 | manta
# Processing Record 18 of Set 6 | san luis de la loma
# Processing Record 19 of Set 6 | melfi
# Processing Record 20 of Set 6 | saipan
# Processing Record 21 of Set 6 | fort mcmurray
# Processing Record 22 of Set 6 | marshall
# Processing Record 23 of Set 6 | borzya
# Processing Record 24 of Set 6 | baruun-urt
# Processing Record 25 of Set 6 | shubarkuduk
# Processing Record 26 of Set 6 | ust'-ilimsk
# Processing Record 27 of Set 6 | makinsk
# Processing Record 28 of Set 6 | agat village
# Processing Record 29 of Set 6 | naliya
# Processing Record 30 of Set 6 | mirnyy
# Processing Record 31 of Set 6 | puerto san carlos
# Processing Record 32 of Set 6 | espinosa
# Processing Record 33 of Set 6 | nuuk
# Processing Record 34 of Set 6 | dudinka
# Processing Record 35 of Set 6 | fondettes
# Processing Record 36 of Set 6 | detroit lakes
# Processing Record 37 of Set 6 | prieska
# Processing Record 38 of Set 6 | mossel bay
# Processing Record 39 of Set 6 | prado
# Processing Record 40 of Set 6 | akdepe
# Processing Record 41 of Set 6 | saint-philippe
# Processing Record 42 of Set 6 | mokhsogollokh
# Processing Record 43 of Set 6 | sorgun
# Processing Record 44 of Set 6 | santa terezinha
# Processing Record 45 of Set 6 | mar del plata
# Processing Record 46 of Set 6 | copperas cove
# Processing Record 47 of Set 6 | ixtapa
# Processing Record 48 of Set 6 | kirensk
# Processing Record 49 of Set 6 | novodvinsk
# Processing Record 0 of Set 7 | labrador city
# Processing Record 1 of Set 7 | runaway bay
# Processing Record 2 of Set 7 | xiaoweizhai
# Processing Record 3 of Set 7 | kone
# Processing Record 4 of Set 7 | tortoli
# Processing Record 5 of Set 7 | akureyri
# Processing Record 6 of Set 7 | inverell
# Processing Record 7 of Set 7 | griffith
# Processing Record 8 of Set 7 | jaguey grande
# Processing Record 9 of Set 7 | cayambe
# Processing Record 10 of Set 7 | tafuna
# Processing Record 11 of Set 7 | cide
# Processing Record 12 of Set 7 | chonchi
# Processing Record 13 of Set 7 | maraba
# Processing Record 14 of Set 7 | tarija
# Processing Record 15 of Set 7 | taoudenni
# Processing Record 16 of Set 7 | ushtobe
# Processing Record 17 of Set 7 | san julian
# Processing Record 18 of Set 7 | la mira
# Processing Record 19 of Set 7 | baixa grande
# Processing Record 20 of Set 7 | santiago de cao
# Processing Record 21 of Set 7 | kedougou
# Processing Record 22 of Set 7 | cedeira
# Processing Record 23 of Set 7 | curvelo
# Processing Record 24 of Set 7 | vila franca do campo
# Processing Record 25 of Set 7 | alice springs
# Processing Record 26 of Set 7 | beloyarskiy
# Processing Record 27 of Set 7 | kapa'a
# Processing Record 28 of Set 7 | alaghsas
# Processing Record 29 of Set 7 | verkhovazh'ye
# Processing Record 30 of Set 7 | quixada
# Processing Record 31 of Set 7 | pibor
# Processing Record 32 of Set 7 | sarakhs
# Processing Record 33 of Set 7 | suileng
# Processing Record 34 of Set 7 | nieuw amsterdam
# Processing Record 35 of Set 7 | gorom-gorom
# Processing Record 36 of Set 7 | dryden
# Processing Record 37 of Set 7 | ahau
# Processing Record 38 of Set 7 | horasan
# Processing Record 39 of Set 7 | utete
# Processing Record 40 of Set 7 | boke
# Processing Record 41 of Set 7 | marsh harbour
# Processing Record 42 of Set 7 | karratha
# Processing Record 43 of Set 7 | ozieri
# Processing Record 44 of Set 7 | akrehamn
# Processing Record 45 of Set 7 | shevchenko
# Processing Record 46 of Set 7 | tabou
# Processing Record 47 of Set 7 | pointe-noire
# Processing Record 48 of Set 7 | yuryuzan'
# Processing Record 49 of Set 7 | mejit
# Processing Record 0 of Set 8 | laojunmiao
# Processing Record 1 of Set 8 | island harbour
# Processing Record 2 of Set 8 | tucurui
# Processing Record 3 of Set 8 | eastham
# Processing Record 4 of Set 8 | nadym
# Processing Record 5 of Set 8 | vorkuta
# Processing Record 6 of Set 8 | gadzhiyevo
# Processing Record 7 of Set 8 | sudislavl'
# Processing Record 8 of Set 8 | jinzhou
# Processing Record 9 of Set 8 | dawei
# Processing Record 10 of Set 8 | lompoc
# Processing Record 11 of Set 8 | pahrump
# Processing Record 12 of Set 8 | hadibu
# Processing Record 13 of Set 8 | tadine
# Processing Record 14 of Set 8 | remire-montjoly
# Processing Record 15 of Set 8 | el granada
# Processing Record 16 of Set 8 | mahabe
# Processing Record 17 of Set 8 | dhuusamarreeb
# Processing Record 18 of Set 8 | uliastay
# Processing Record 19 of Set 8 | laguna
# Processing Record 20 of Set 8 | santa maria de jetiba
# Processing Record 21 of Set 8 | noumea
# Processing Record 22 of Set 8 | kimberley
# Processing Record 23 of Set 8 | sinop
# Processing Record 24 of Set 8 | charleston
# Processing Record 25 of Set 8 | lop buri
# Processing Record 26 of Set 8 | quelimane
# Processing Record 27 of Set 8 | er regueb
# Processing Record 28 of Set 8 | sanghar
# Processing Record 29 of Set 8 | la passe
# Processing Record 30 of Set 8 | ulanhot
# Processing Record 31 of Set 8 | antibes
# Processing Record 32 of Set 8 | pyt-yakh
# Processing Record 33 of Set 8 | skarzysko-kamienna
# Processing Record 34 of Set 8 | wenling
# Processing Record 35 of Set 8 | mawlaik
# Processing Record 36 of Set 8 | ta`u
# Processing Record 37 of Set 8 | vernon
# Processing Record 38 of Set 8 | torre de moncorvo
# Processing Record 39 of Set 8 | altay
# Processing Record 40 of Set 8 | siwa oasis
# Processing Record 41 of Set 8 | nar'yan-mar
# Processing Record 42 of Set 8 | constantia
# Processing Record 43 of Set 8 | shihezi
# Processing Record 44 of Set 8 | coquimbo
# Processing Record 45 of Set 8 | baiti
# Processing Record 46 of Set 8 | roccella ionica
# Processing Record 47 of Set 8 | piney green
# Processing Record 48 of Set 8 | fale old settlement
# Processing Record 49 of Set 8 | alesund
# Processing Record 0 of Set 9 | pathein
# Processing Record 1 of Set 9 | usinsk
# Processing Record 2 of Set 9 | belyy yar
# Processing Record 3 of Set 9 | tres coroas
# Processing Record 4 of Set 9 | tachilek
# Processing Record 5 of Set 9 | meadow lakes
# Processing Record 6 of Set 9 | feijo
# Processing Record 7 of Set 9 | kalmunai
# Processing Record 8 of Set 9 | port saint john's
# Processing Record 9 of Set 9 | bayevo
# Processing Record 10 of Set 9 | ust-tsilma
# Processing Record 11 of Set 9 | ambon
# Processing Record 12 of Set 9 | sinan
# Processing Record 13 of Set 9 | kolonia town
# Processing Record 14 of Set 9 | mhamid
# Processing Record 15 of Set 9 | christchurch
# Processing Record 16 of Set 9 | auki
# Processing Record 17 of Set 9 | manicore
# Processing Record 18 of Set 9 | manikpur
# Processing Record 19 of Set 9 | leninkent
# Processing Record 20 of Set 9 | tanjung pinang
# Processing Record 21 of Set 9 | forster
# Processing Record 22 of Set 9 | vyalikaya byerastavitsa
# Processing Record 23 of Set 9 | kondopoga
# Processing Record 24 of Set 9 | vilyuchinsk
# Processing Record 25 of Set 9 | grand gaube
# Processing Record 26 of Set 9 | yujing
# Processing Record 27 of Set 9 | mount pearl
# Processing Record 28 of Set 9 | tahmoor
# Processing Record 29 of Set 9 | grand falls-windsor
# Processing Record 30 of Set 9 | utrik
# Processing Record 31 of Set 9 | lorengau
# Processing Record 32 of Set 9 | port victoria
# Processing Record 33 of Set 9 | tual
# Processing Record 34 of Set 9 | kulia village
# Processing Record 35 of Set 9 | masterton
# Processing Record 36 of Set 9 | kutiatodu
# Processing Record 37 of Set 9 | khorol'
# Processing Record 38 of Set 9 | harar
# Processing Record 39 of Set 9 | launceston
# Processing Record 40 of Set 9 | inhambane
# Processing Record 41 of Set 9 | antsohihy
# Processing Record 42 of Set 9 | isnos
# Processing Record 43 of Set 9 | urengoy
# Processing Record 44 of Set 9 | la union
# Processing Record 45 of Set 9 | tumayr
# Processing Record 46 of Set 9 | polur
# Processing Record 47 of Set 9 | kwali
# Processing Record 48 of Set 9 | walla walla
# Processing Record 49 of Set 9 | la entrada
# Processing Record 0 of Set 10 | melekeok village
# Processing Record 1 of Set 10 | sillamae
# Processing Record 2 of Set 10 | robertsport
# Processing Record 3 of Set 10 | saint-francois
# Processing Record 4 of Set 10 | birobidzhan
# Processing Record 5 of Set 10 | teluk nibung
# Processing Record 6 of Set 10 | constitucion
# Processing Record 7 of Set 10 | peniche
# Processing Record 8 of Set 10 | mendig
# Processing Record 9 of Set 10 | acarau
# Processing Record 10 of Set 10 | kayangel
# Processing Record 11 of Set 10 | champerico
# Processing Record 12 of Set 10 | port glaud
# Processing Record 13 of Set 10 | san jose
# Processing Record 14 of Set 10 | isla mujeres
# Processing Record 15 of Set 10 | tofol
# Processing Record 16 of Set 10 | enriquillo
# Processing Record 17 of Set 10 | anyang
# Processing Record 18 of Set 10 | isle of lewis
# Processing Record 19 of Set 10 | 'ohonua
# Processing Record 20 of Set 10 | mount isa
# Processing Record 21 of Set 10 | huarmey
# Processing Record 22 of Set 10 | khamis mushait
# Processing Record 23 of Set 10 | solleftea
# Processing Record 24 of Set 10 | ritchie
# Processing Record 25 of Set 10 | nha trang
# Processing Record 26 of Set 10 | bikenibeu village
# Processing Record 27 of Set 10 | nagqu
# Processing Record 28 of Set 10 | namibe
# Processing Record 29 of Set 10 | monticello
# Processing Record 30 of Set 10 | turpan
# Processing Record 31 of Set 10 | camocim
# Processing Record 32 of Set 10 | kose
# Processing Record 33 of Set 10 | zhosaly
# Processing Record 34 of Set 10 | totness
# Processing Record 35 of Set 10 | tranovaho
# Processing Record 36 of Set 10 | carnarvon
# Processing Record 37 of Set 10 | schuyler
# Processing Record 38 of Set 10 | rawlins
# Processing Record 39 of Set 10 | yemva
# Processing Record 40 of Set 10 | jose mariano jimenez
# Processing Record 41 of Set 10 | bridgewater
# Processing Record 42 of Set 10 | arar
# Processing Record 43 of Set 10 | dobrotesti
# Processing Record 44 of Set 10 | nova cruz
# Processing Record 45 of Set 10 | sokol'skoye
# Processing Record 46 of Set 10 | taulaga
# Processing Record 47 of Set 10 | bria
# Processing Record 48 of Set 10 | pont rouge
# Processing Record 49 of Set 10 | beau vallon
# Processing Record 0 of Set 11 | salair
# Processing Record 1 of Set 11 | ataq
# Processing Record 2 of Set 11 | palu
# Processing Record 3 of Set 11 | cooper's town
# Processing Record 4 of Set 11 | westport
# Processing Record 5 of Set 11 | holualoa
# Processing Record 6 of Set 11 | yesilhisar
# Processing Record 7 of Set 11 | cozumel
# Processing Record 8 of Set 11 | dingzhou
# Processing Record 9 of Set 11 | kodinsk
# Processing Record 10 of Set 11 | la ronge
# Processing Record 11 of Set 11 | arkhangel'sk
# Processing Record 12 of Set 11 | maile
# Processing Record 13 of Set 11 | pandan
# Processing Record 14 of Set 11 | kiunga
# Processing Record 15 of Set 11 | dongola
# Processing Record 16 of Set 11 | yaren
# Processing Record 17 of Set 11 | nova sintra
# Processing Record 18 of Set 11 | waiuku
# Processing Record 19 of Set 11 | gandajika
# Processing Record 20 of Set 11 | san antonio de pale
# Processing Record 21 of Set 11 | mudon
# Processing Record 22 of Set 11 | bougouni
# Processing Record 23 of Set 11 | kruisfontein
# Processing Record 24 of Set 11 | abu dhabi
# Processing Record 25 of Set 11 | biala podlaska
# Processing Record 26 of Set 11 | magong
# Processing Record 27 of Set 11 | monywa
# Processing Record 28 of Set 11 | callao
# Processing Record 29 of Set 11 | berdigestyakh
# Processing Record 30 of Set 11 | al manshah
# Processing Record 31 of Set 11 | thinadhoo
# Processing Record 32 of Set 11 | chabahar
# Processing Record 33 of Set 11 | marang
# Processing Record 34 of Set 11 | rochelle
# Processing Record 35 of Set 11 | oriximina
# Processing Record 36 of Set 11 | nemuro
# Processing Record 37 of Set 11 | camana
# Processing Record 38 of Set 11 | sur
# Processing Record 39 of Set 11 | nalut
# Processing Record 40 of Set 11 | vadso
# Processing Record 41 of Set 11 | koz'modem'yansk
# Processing Record 42 of Set 11 | martapura
# Processing Record 43 of Set 11 | caraballeda
# Processing Record 44 of Set 11 | mulino
# Processing Record 45 of Set 11 | shelekhov
# Processing Record 46 of Set 11 | shanghai
# Processing Record 47 of Set 11 | rio gallegos
# Processing Record 48 of Set 11 | buka
# Processing Record 49 of Set 11 | sen monorom
# Processing Record 0 of Set 12 | villa alberto andres alvarado aramburo
# Processing Record 1 of Set 12 | aoulef
# Processing Record 2 of Set 12 | teknaf
# Processing Record 3 of Set 12 | gebeit
# Processing Record 4 of Set 12 | san matias
# Processing Record 5 of Set 12 | watsa
# Processing Record 6 of Set 12 | razole
# Processing Record 7 of Set 12 | tamanrasset
# Processing Record 8 of Set 12 | middletown
# Processing Record 9 of Set 12 | sandnessjoen
# Processing Record 10 of Set 12 | cidade velha
# Processing Record 11 of Set 12 | midvagur
# Processing Record 12 of Set 12 | balikpapan
# Processing Record 13 of Set 12 | horta
# Processing Record 14 of Set 12 | marathon
# Processing Record 15 of Set 12 | severo-yeniseyskiy
# Processing Record 16 of Set 12 | rehoboth
# City not found. Skipping...
# Processing Record 17 of Set 12 | aginskoye
# Processing Record 18 of Set 12 | kasongo-lunda
# Processing Record 19 of Set 12 | hays
# Processing Record 20 of Set 12 | lae
# Processing Record 21 of Set 12 | port macquarie
# Processing Record 22 of Set 12 | slave lake
# Processing Record 23 of Set 12 | amga
# Processing Record 24 of Set 12 | aswan
# Processing Record 25 of Set 12 | aral
# Processing Record 26 of Set 12 | nafada
# Processing Record 27 of Set 12 | mongoumba
# Processing Record 28 of Set 12 | cable beach
# Processing Record 29 of Set 12 | prince george
# Processing Record 30 of Set 12 | okha
# Processing Record 31 of Set 12 | taltal
# Processing Record 32 of Set 12 | ishigaki
# Processing Record 33 of Set 12 | rio grande
# Processing Record 34 of Set 12 | kharp
# Processing Record 35 of Set 12 | santa rosa del sara
# Processing Record 36 of Set 12 | jaroslaw
# Processing Record 37 of Set 12 | argenton-sur-creuse
# Processing Record 38 of Set 12 | mahalapye
# Processing Record 39 of Set 12 | honcho
# Processing Record 40 of Set 12 | paita
# Processing Record 41 of Set 12 | novyy urgal
# Processing Record 42 of Set 12 | devils lake
# Processing Record 43 of Set 12 | cargados carajos
# Processing Record 44 of Set 12 | o barco de valdeorras
# Processing Record 45 of Set 12 | fuvahmulah
# Processing Record 46 of Set 12 | kulhudhuffushi
# Processing Record 47 of Set 12 | saryozek
# Processing Record 48 of Set 12 | sturlic
# Processing Record 49 of Set 12 | binkolo
# Processing Record 0 of Set 13 | ampara
# Processing Record 1 of Set 13 | vila do maio
# Processing Record 2 of Set 13 | podilsk
# Processing Record 3 of Set 13 | preobrazheniye
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          603
# Lat           603
# Lng           603
# Max Temp      603
# Humidity      603
# Cloudiness    603
# Wind Speed    603
# Country       603
# Date          603
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                City      Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       olonkinbyen  51.5085 -0.1257    285.37        75          75
# 1            bethel  51.5085 -0.1257    285.37        75          75
# 2      longyearbyen  51.5085 -0.1257    285.37        75          75
# 3         grytviken  51.5085 -0.1257    285.37        75          75
# 4  minas de marcona  51.5085 -0.1257    285.37        75          75
#
#    Wind Speed Country        Date
# 0        5.14      GB  1686012001
# 1        5.14      GB  1686012001
# 2        5.14      GB  1686012001
# 3        5.14      GB  1686012001
# 4        5.14      GB  1686012001

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data\cities.csv")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="Unnamed: 0")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       olonkinbyen  51.5085 -0.1257    285.37        75          75
# 1            bethel  51.5085 -0.1257    285.37        75          75
# 2      longyearbyen  51.5085 -0.1257    285.37        75          75
# 3         grytviken  51.5085 -0.1257    285.37        75          75
# 4  minas de marcona  51.5085 -0.1257    285.37        75          75
#
#    Wind Speed Country        Date
# 0        5.14      GB  1686012001
# 1        5.14      GB  1686012001
# 2        5.14      GB  1686012001
# 3        5.14      GB  1686012001
# 4        5.14      GB  1686012001

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Create a scatter plot of Latitude vs. Temperature
city_data_df.plot(kind="scatter", x="Lat", y="Max Temp", figsize=(8,6))

# Set the title and labels
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Create a scatter plot of Latitude vs. Humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", s=10)

# Set the chart title and labels
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Set the y-axis limit
plt.ylim(0, 100)

# Set the grid lines
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Create a scatter plot of Latitude vs. Cloudiness
city_data_df.plot(kind="scatter", x="Lat", y="Cloudiness", figsize=(8,6))

# Set the title and labels
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create a scatter plot of Latitude vs. Wind Speed
city_data_df.plot(kind="scatter", x="Lat", y="Wind Speed", figsize=(8,6))

# Set the title and labels
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label, title, text_coordinates):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       olonkinbyen  51.5085 -0.1257    285.37        75          75
# 1            bethel  51.5085 -0.1257    285.37        75          75
# 2      longyearbyen  51.5085 -0.1257    285.37        75          75
# 3         grytviken  51.5085 -0.1257    285.37        75          75
# 4  minas de marcona  51.5085 -0.1257    285.37        75          75
#
#    Wind Speed Country        Date
# 0        5.14      GB  1686012001
# 1        5.14      GB  1686012001
# 2        5.14      GB  1686012001
# 3        5.14      GB  1686012001
# 4        5.14      GB  1686012001

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# Create scatter plot of Latitude vs. Max Temperature for northern hemisphere
northern_hemi_df.plot(kind="scatter", x="Lat", y="Max Temp", figsize=(8,6))

# Define parameters for linear regression function
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
x_label = "Latitude"
y_label = "Max Temperature (F)"
title = "Northern Hemisphere - City Latitude vs. Max Temperature (%s)" % time.strftime("%x")
text_coordinates = (0, -30)

# Call linear regression function
plot_linear_regression(x_values, y_values, x_label, y_label, title, text_coordinates)

# Display plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21900\2126065988.py in <module>
#      12
#      13 # Call linear regression function
# ---> 14 plot_linear_regression(x_values, y_values, x_label, y_label, title, text_coordinates)
#      15
#      16 # Display plot
#
# ~\AppData\Local\Temp\ipykernel_21900\1851817856.py in plot_linear_regression(x_values, y_values, x_label, y_label, title, text_coordinates)
#       2 def plot_linear_regression(x_values, y_values, x_label, y_label, title, text_coordinates):
#       3     # Perform linear regression
# ----> 4     (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#       5     regress_values = x_values * slope + intercept
#       6     line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#
# ~\anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y, alternative)
#     154
#     155     if np.amax(x) == np.amin(x) and len(x) > 1:
# --> 156         raise ValueError("Cannot calculate a linear regression "
#     157                          "if all x values are identical")
#     158
#
# ValueError: Cannot calculate a linear regression if all x values are identical

# %%
# Linear regression on Southern Hemisphere
# Create scatter plot of Latitude vs. Max Temperature for southern hemisphere
southern_hemi_df.plot(kind="scatter", x="Lat", y="Max Temp", figsize=(8,6))

# Define parameters for linear regression function
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
x_label = "Latitude"
y_label = "Max Temperature (F)"
title = "Southern Hemisphere - City Latitude vs. Max Temperature (%s)" % time.strftime("%x")
text_coordinates = (-55, 90)

# Call linear regression function
plot_linear_regression(x_values, y_values, x_label, y_label, title, text_coordinates)

# Display plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21900\325423137.py in <module>
#      12
#      13 # Call linear regression function
# ---> 14 plot_linear_regression(x_values, y_values, x_label, y_label, title, text_coordinates)
#      15
#      16 # Display plot
#
# ~\AppData\Local\Temp\ipykernel_21900\1851817856.py in plot_linear_regression(x_values, y_values, x_label, y_label, title, text_coordinates)
#       2 def plot_linear_regression(x_values, y_values, x_label, y_label, title, text_coordinates):
#       3     # Perform linear regression
# ----> 4     (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#       5     regress_values = x_values * slope + intercept
#       6     line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#
# ~\anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y, alternative)
#     151
#     152     if x.size == 0 or y.size == 0:
# --> 153         raise ValueError("Inputs must not be empty.")
#     154
#     155     if np.amax(x) == np.amin(x) and len(x) > 1:
#
# ValueError: Inputs must not be empty.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Create scatter plot of Latitude vs. Humidity for northern hemisphere
northern_hemi_df.plot(kind="scatter", x="Lat", y="Humidity", figsize=(8,6))

# Define parameters for linear regression function
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
x_label = "Latitude"
y_label = "Humidity (%)"
title = "Northern Hemisphere - City Latitude vs. Humidity (%s)" % time.strftime("%x")
text_coordinates = (45, 10)

# Call linear regression function
plot_linear_regression(x_values, y_values, x_label, y_label, title, text_coordinates)

# Display plot
plt.show()

# %%
# Southern Hemisphere
# Create scatter plot of Latitude vs. Humidity for southern hemisphere
southern_hemi_df.plot(kind="scatter", x="Lat", y="Humidity", figsize=(8,6))

# Define parameters for linear regression function
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
x_label = "Latitude"
y_label = "Humidity (%)"
title = "Southern Hemisphere - City Latitude vs. Humidity (%s)" % time.strftime("%x")
text_coordinates = (-55, 20)

# Call linear regression function
plot_linear_regression(x_values, y_values, x_label, y_label, title, text_coordinates)

# Display plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Create scatter plot of Latitude vs. Cloudiness for northern hemisphere
northern_hemi_df.plot(kind="scatter", x="Lat", y="Cloudiness", figsize=(8,6))

# Define parameters for linear regression function
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
x_label = "Latitude"
y_label = "Cloudiness (%)"
title = "Northern Hemisphere - City Latitude vs. Cloudiness (%s)" % time.strftime("%x")
text_coordinates = (45, 10)

# Call linear regression function
plot_linear_regression(x_values, y_values, x_label, y_label, title, text_coordinates)

# Display plot
plt.show()

# %%
# Southern Hemisphere
# Create scatter plot of Latitude vs. Cloudiness for southern hemisphere
southern_hemisphere_df.plot(kind="scatter", x="Lat", y="Cloudiness", figsize=(8,6))

# Define parameters for linear regression function
x_values = southern_hemisphere_df["Lat"]
y_values = southern_hemisphere_df["Cloudiness"]
x_label = "Latitude"
y_label = "Cloudiness (%)"
title = "Southern Hemisphere - City Latitude vs. Cloudiness (%s)" % time.strftime("%x")
text_coordinates = (-55, 60)

# Call linear regression function
plot_linear_regression(x_values, y_values, x_label, y_label, title, text_coordinates)

# Display plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Create scatter plot of Latitude vs. Wind Speed for northern hemisphere
northern_hemi_df.plot(kind="scatter", x="Lat", y="Wind Speed", figsize=(8,6))

# Define parameters for linear regression function
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
x_label = "Latitude"
y_label = "Wind Speed (mph)"
title = "Northern Hemisphere - City Latitude vs. Wind Speed (%s)" % time.strftime("%x")
text_coordinates = (10, 25)

# Call linear regression function
plot_linear_regression(x_values, y_values, x_label, y_label, title, text_coordinates)

# Display plot
plt.show()

# %%
# Southern Hemisphere
# Create scatter plot of Latitude vs. Wind Speed for southern hemisphere
southern_hemisphere_df.plot(kind="scatter", x="Lat", y="Wind Speed", figsize=(8,6))

# Define parameters for linear regression function
x_values = southern_hemisphere_df["Lat"]
y_values = southern_hemisphere_df["Wind Speed"]
x_label = "Latitude"
y_label = "Wind Speed (mph)"
title = "Southern Hemisphere - City Latitude vs. Wind Speed (%s)" % time.strftime("%x")
text_coordinates = (-55, 25)

# Call linear regression function
plot_linear_regression(x_values, y_values, x_label, y_label, title, text_coordinates)

# Display plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
